# %% [markdown]
# <a href="https://colab.research.google.com/github/aadhavjawahar-sys/Skin-classification-Random-Forest/blob/main/RF_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Get neccessary imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier

# %%
#Data
url = "https://raw.githubusercontent.com/aadhavjawahar-sys/Cardiotocography-Random-Forest/refs/heads/main/Skin_NonSkin.txt"

# Parse datafile --- Columns: Blue, Green, Red, Class (0 = Skin, 1 = Non-Skin)
df = pd.read_csv(url, sep="\t", header=None, names=["B", "G", "R", "Class"])
df["Class"] = df["Class"]-1

df.head()
# Out:
#     B   G    R  Class
# 0  74  85  123      0
# 1  73  84  122      0
# 2  72  83  121      0
# 3  70  81  119      0
# 4  70  81  119      0

# %%
#Separate training and testing sets
X = df.drop(columns=["Class"])
y=df["Class"]
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=2026,test_size=0.20,stratify=y)

# %%
#Create and train Random Forest CLassifier, and record predicted values
model = RandomForestClassifier(max_depth=8, max_features=2, n_estimators=500)
model.fit(X_train, y_train)
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

# %%
#Output the accuracy report
print(classification_report(y_train, y_pred_train))
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     40687
#            1       1.00      0.99      1.00    155358
#
#     accuracy                           1.00    196045
#    macro avg       0.99      1.00      0.99    196045
# weighted avg       1.00      1.00      1.00    196045
#
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     10172
#            1       1.00      0.99      1.00     38840
#
#     accuracy                           1.00     49012
#    macro avg       0.99      1.00      0.99     49012
# weighted avg       1.00      1.00      1.00     49012

# %%
#GUI
import gradio as gr

def skin_status_check(B,G,R):
    input_df = pd.DataFrame(
        [
            {
                "B": B,
                "G": G,
                "R": R,
            }
        ]
    )
    return ("Non-Skin" if (model.predict(input_df)[0]) else "Skin")
demo = gr.Interface(
    fn=skin_status_check,
    inputs=[
        gr.Number(label="B", value=255),
        gr.Number(label="G", value=255),
        gr.Number(label="R", value=255),
        ],
    outputs=["text"],
    api_name="predict"
)

demo.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://4fdf52d1ab7a6b50df.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://4fdf52d1ab7a6b50df.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
